# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel('INX_Future_Inc.xls')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
# EmpNumber                       1200 non-null object
# Age                             1200 non-null int64
# Gender                          1200 non-null object
# EducationBackground             1200 non-null object
# MaritalStatus                   1200 non-null object
# EmpDepartment                   1200 non-null object
# EmpJobRole                      1200 non-null object
# BusinessTravelFrequency         1200 non-null object
# DistanceFromHome                1200 non-null int64
# EmpEducationLevel               1200 non-null int64
# EmpEnvironmentSatisfaction      1200 non-null int64
# EmpHourlyRate                   1200 non-null int64
# EmpJobInvolvement               1200 non-null int64
# EmpJobLevel                     1200 non-null int64
# EmpJobSatisfaction              1200 non-null int64
# NumCompaniesWorked              1200 non-null int64
# ...

# %%
data.drop(['EmpNumber','Age'],axis=1,inplace=True)

# %%
data.head(2)
# Out:
#   Gender EducationBackground MaritalStatus EmpDepartment       EmpJobRole  \
# 0   Male           Marketing        Single         Sales  Sales Executive
# 1   Male           Marketing        Single         Sales  Sales Executive
#
#   BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0           Travel_Rarely                10                  3
# 1           Travel_Rarely                14                  4
#
#    EmpEnvironmentSatisfaction  EmpHourlyRate  ...  \
# 0                           4             55  ...
# 1                           4             42  ...
#
#    EmpRelationshipSatisfaction  TotalWorkExperienceInYears  \
# 0                            4                          10
# 1                            4                          20
#
#    TrainingTimesLastYear  EmpWorkLifeBalance ExperienceYearsAtThisCompany  \
# 0                      2                   2                           10
# ...

# %%
plt.figure(figsize=(20,20))
sns.pairplot(data)

# %%
sns.barplot('EmpHourlyRate','BusinessTravelFrequency',data=data)

# %%
sns.barplot('OverTime','EmpHourlyRate',data=data)

# %%
sns.barplot('OverTime','PerformanceRating',data=data)

# %%
from sklearn.feature_selection import chi2

# %%
data=pd.get_dummies(data,drop_first=True)

# %%
p=chi2(data.drop('PerformanceRating',axis=1),data['PerformanceRating'])

# %%
l1=p[1]<0.05

# %%
l2=data.columns

# %%
d={}
d=dict(zip(l2,l1))

# %%
d
# Out:
# {'DistanceFromHome': True,
#  'EmpEducationLevel': False,
#  'EmpEnvironmentSatisfaction': True,
#  'EmpHourlyRate': True,
#  'EmpJobInvolvement': False,
#  'EmpJobLevel': True,
#  'EmpJobSatisfaction': False,
#  'NumCompaniesWorked': False,
#  'EmpLastSalaryHikePercent': True,
#  'EmpRelationshipSatisfaction': False,
#  'TotalWorkExperienceInYears': True,
#  'TrainingTimesLastYear': False,
#  'EmpWorkLifeBalance': False,
#  'ExperienceYearsAtThisCompany': True,
#  'ExperienceYearsInCurrentRole': True,
#  'YearsSinceLastPromotion': True,
#  'YearsWithCurrManager': True,
#  'PerformanceRating': False,
#  'Gender_Male': False,
#  'EducationBackground_Life Sciences': False,
#  'EducationBackground_Marketing': False,
#  'EducationBackground_Medical': True,
#  'EducationBackground_Other': False,
#  'EducationBackground_Technical Degree': False,
#  'MaritalStatus_Married': False,
#  'MaritalStatus_Single': True,
#  'EmpDepartment_Development': True,
#  'EmpDepartment_Finance': False,
# ...
